# %%
import pandas as pd

# %%
df = pd.load_csv("D:\Developer\UPI\upi_synthetic_dataset.csv")
df
# Out:
#   Cell In[2], line 1
#     df = pd.load_csv("D:\Developer\UPI\upi_synthetic_dataset.csv")
#                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 12-13: truncated \UXXXXXXXX escape
